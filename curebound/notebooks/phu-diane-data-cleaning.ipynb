# %% [markdown]
# Authors: Phu Dang and Diane Dinh
#
# Purpose: Pedal ROI Data Cleaning
#
# Date: 05.06.2023
#
# Number of projects per investment pillar (AG-AK) (Phu & Diane) \
# Name of project title and clinical trials(DA-DG) (Phu & Diane) \
# Number of peer-reviewed publications (DM) (Phu & Diane) \
# Name of project titles that will lead to improvements in health policy (FD, FL) (Phu & Diane)

# %%
# Importing libraries and packages

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px
import os

# pd.set_option('display.max_rows', None)
# Adjust dataframe display options to view full output
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# Reset to default ~ comment 2 lines above and 
# uncomment 2 lines below, run all before pushing to GitHub
# pd.set_option('display.max_columns', 20)
# pd.set_option('display.width', 80)

# %%
# Read dataset

os.chdir('../data')
fp = os.path.join('raw', '2022_Pedal_ROI_RAW_DATA_Biokind.xlsx').replace("\\","/")
df = pd.read_excel(fp)
df.head(5)
# Out:
#    Record ID          Event Name  Data Access Group  Survey Identifier  \
# 0        3.0             Initial                NaN                NaN
# 1        3.0  Progress Report #1                NaN                NaN
# 2        4.0             Initial                NaN                NaN
# 3        4.0  Progress Report #1                NaN                NaN
# 4        5.0             Initial                NaN                NaN
#
#    Award ID                         What is the project title?  \
# 0       3.1  Detecting dysregulated genes in neuroblastoma ...
# 1       NaN                                                NaN
# 2       4.1  Functional Roles for Histidine Kinase Signalin...
# 3       NaN                                                NaN
# 4       5.1  A National Phase I Study of Cabozantinib in Co...
#
#   What is the PI's First Name? What is the PI's last name?   PI degree  \
# 0                       Graham                    McVicker         PhD
# ...

# %%
df['Event Name'].unique()
# Out:
# array(['Initial', 'Progress Report #1'], dtype=object)

# %%
roi = df[df['Event Name'] == 'Initial']
pr = df[df['Event Name'] == 'Progress Report #1']
roi.head()
# Out:
#    Record ID Event Name  Data Access Group  Survey Identifier  Award ID  \
# 0        3.0    Initial                NaN                NaN       3.1
# 2        4.0    Initial                NaN                NaN       4.1
# 4        5.0    Initial                NaN                NaN       5.1
# 6        6.0    Initial                NaN                NaN       6.1
# 8        8.0    Initial                NaN                NaN       8.1
#
#                           What is the project title?  \
# 0  Detecting dysregulated genes in neuroblastoma ...
# 2  Functional Roles for Histidine Kinase Signalin...
# 4  A National Phase I Study of Cabozantinib in Co...
# 6  UCSD-UCSF Specialized Program of Research Exce...
# 8  A Phase 1B, Nonrandomized Trial Investigating ...
#
#   What is the PI's First Name? What is the PI's last name?   PI degree  \
# 0                       Graham                    McVicker         PhD
# ...

# %%
print(pr.shape)
pr.head()
# Out:
# (104, 232)
#    Record ID          Event Name  Data Access Group  Survey Identifier  \
# 1        3.0  Progress Report #1                NaN                NaN
# 3        4.0  Progress Report #1                NaN                NaN
# 5        5.0  Progress Report #1                NaN                NaN
# 7        6.0  Progress Report #1                NaN                NaN
# 9        8.0  Progress Report #1                NaN                NaN
#
#    Award ID What is the project title? What is the PI's First Name?  \
# 1       NaN                        NaN                          NaN
# 3       NaN                        NaN                          NaN
# 5       NaN                        NaN                          NaN
# 7       NaN                        NaN                          NaN
# 9       NaN                        NaN                          NaN
#
#   What is the PI's last name? PI degree If other degree, please specify  \
# ...

# %%
# Drop all completely empty columns

all_empty_cols = pr.isna().sum() == 104
to_drop = all_empty_cols[all_empty_cols].index

# %%
pr = pr.drop(columns=to_drop)

# %%
pr.head(5)
# Out:
#    Record ID          Event Name  \
# 1        3.0  Progress Report #1
# 3        4.0  Progress Report #1
# 5        5.0  Progress Report #1
# 7        6.0  Progress Report #1
# 9        8.0  Progress Report #1
#
#   Status of the fourth Peer Reviewed Publication associated with this support.   \
# 1                                                NaN
# 3                                                NaN
# 5                                                NaN
# 7                                                NaN
# 9                                                NaN
#
#   Fourth DOI # Fourth PMID or PMCID  \
# 1          NaN                  NaN
# 3          NaN                  NaN
# 5          NaN                  NaN
# 7          NaN                  NaN
# 9          NaN                  NaN
#
#   Status of the fifth Peer Reviewed Publication associated with this support.   \
# 1                                                NaN
# ...

# %%
print(len(pr.columns.to_list()))
print(pr.columns.to_list())
# Out:
# 105
# ...

# %%
# Shortening column names

# Dict for renaming columns
column_mapping = {
    'Record ID': 'ID',
    'Status of the fourth Peer Reviewed Publication associated with this support. ': 'Publication Status 4', 
    'Status of the fifth Peer Reviewed Publication associated with this support. ': 'Publication Status 5', 
    'Status of the sixth Peer Reviewed Publication associated with this support. ': 'Publication Status 6', 
    'Status of the seventh Peer Reviewed Publication associated with this support. ': 'Publication Status 7',
    'Status of the eighth Peer Reviewed Publication associated with this support. ': 'Publication Status 8', 
    'Status of the ninth Peer Reviewed Publication associated with this support. ': 'Publication Status 9',
    'Status of the tenth Peer Reviewed Publication associated with this support. ': 'Publication Status 10', 
    'List your presentations, abstracts, book chapters or other publications (non-peer reviewed) associated with Pedal the Cause support': 'Pedal Non-Peer Pubs', 
    'Add the details of any other accomplishments due to the support of Pedal the Cause': 'Other Accomplishments', 
    'HEALTH GAINS:  Will the findings from your project benefit health (e.g., prevention, detection, and/or treatment of cancer) and/or health behaviors? ': 'Health Benefits',
    'If yes, please categorize the level(s) at which your research will benefit health and/or health behaviors (select all that apply)   (choice=International)': 'International', 
    'If yes, please categorize the level(s) at which your research will benefit health and/or health behaviors (select all that apply)   (choice=National)': 'National', 
    'If yes, please categorize the level(s) at which your research will benefit health and/or health behaviors (select all that apply)   (choice=Local (e.g., hospital))': 'Local', 
    'If yes, please categorize the level(s) at which your research will benefit health and/or health behaviors (select all that apply)   (choice=General public)': 'General Public', 
    'If yes, please categorize the level(s) at which your research will benefit health and/or health behaviors (select all that apply)   (choice=Healthcare Professionals)': 'Healthcare Professionals',
    'If yes, please categorize the level(s) at which your research will benefit health and/or health behaviors (select all that apply)   (choice=Patients)': 'Patients', 
    'If yes, please categorize the level(s) at which your research will benefit health and/or health behaviors (select all that apply)   (choice=Patient families)': 'Patient Families', 
    'POLICY INFLUENCE: Will the findings from your project lead to improvements in health policy/health decision making (e.g., clinical guidelines, curriculum for teaching or training)?   ': 'Policy Influence', 
    'If yes, please categorize the level(s) at which your research will lead to improvements in health policy/health decision making (select all that apply). (choice=International)': 'International (pol)', 
    'If yes, please categorize the level(s) at which your research will lead to improvements in health policy/health decision making (select all that apply). (choice=National)': 'National (pol)', 
    'If yes, please categorize the level(s) at which your research will lead to improvements in health policy/health decision making (select all that apply). (choice=Local (e.g., hospital))': 'Local (pol)', 
    'If yes, please categorize the level(s) at which your research will lead to improvements in health policy/health decision making (select all that apply). (choice=General public)': 'General Public (pol)', 
    'If yes, please categorize the level(s) at which your research will lead to improvements in health policy/health decision making (select all that apply). (choice=Healthcare Professionals)': 'Healthcare Professionals (pol)',
    'If yes, please categorize the level(s) at which your research will lead to improvements in health policy/health decision making (select all that apply). (choice=Patients)': 'Patients (pol)', 
    'If yes, please categorize the level(s) at which your research will lead to improvements in health policy/health decision making (select all that apply). (choice=Patient families)': 'Patient Families (pol)', 
    'Please describe the health policy/health decision making improvements expected from your project.': 'Policy Benefits Description', 
    'ECONOMIC BENEFITS:  Will the findings from your project lead to improvements in health care service cost and/or health care service delivery?': 'Economic Benefits', 
    'If yes, please categorize the level(s) at which your research will benefit health care service cost and/or health care service delivery (select all that apply) (choice=International)': 'International (econ)', 
    'If yes, please categorize the level(s) at which your research will benefit health care service cost and/or health care service delivery (select all that apply) (choice=National)': 'National (econ)', 
    'If yes, please categorize the level(s) at which your research will benefit health care service cost and/or health care service delivery (select all that apply) (choice=Local (e.g., hospital))': 'Local (econ)', 
    'If yes, please categorize the level(s) at which your research will benefit health care service cost and/or health care service delivery (select all that apply) (choice=General public)': 'General Public (econ)', 
    'If yes, please categorize the level(s) at which your research will benefit health care service cost and/or health care service delivery (select all that apply) (choice=Healthcare Professionals)': 'Healthcare Professionals (econ)', 
    'If yes, please categorize the level(s) at which your research will benefit health care service cost and/or health care service delivery (select all that apply) (choice=Patients)': 'Patients (econ)', 
    'If yes, please categorize the level(s) at which your research will benefit health care service cost and/or health care service delivery (select all that apply) (choice=Patient families)': 'Patient Families (econ)',
    'Please describe the economic/service delivery benefits expected from your project.': 'Economic Benefits Description', 
    'HEALTH CARE EQUITY:  Will the findings from your project lead to an increase in equity for any aspect of cancer health care, health policy and/or service cost?': 'Equity Benefits', 
    'If yes, please categorize the level(s) at which your research will lead to an increase in equity (select all that apply) (choice=International)': 'International (equity)', 
    'If yes, please categorize the level(s) at which your research will lead to an increase in equity (select all that apply) (choice=National)': 'National (equity)', 
    'If yes, please categorize the level(s) at which your research will lead to an increase in equity (select all that apply) (choice=Local (e.g., hospital))': 'Local (equity)', 
    'If yes, please categorize the level(s) at which your research will lead to an increase in equity (select all that apply) (choice=General public)': 'General Public (equity)', 
    'If yes, please categorize the level(s) at which your research will lead to an increase in equity (select all that apply) (choice=Healthcare Professionals)': 'Healthcare Professionals (equity)', 
    'If yes, please categorize the level(s) at which your research will lead to an increase in equity (select all that apply) (choice=Patients)': 'Patients (equity)', 
    'If yes, please categorize the level(s) at which your research will lead to an increase in equity (select all that apply) (choice=Patient families)': 'Patient Families (equity)', 
    'Please describe the way in which your project will lead to an increase in equity.': 'Equity Benefits Description',
    'How many additional funding sources have you planned, submitted, or been awarded (directly or indirectly) as a result of this Padres Pedal the Cause support? (e.g., grants of any type, awards, philanthropy, etc.)?': 'Additional Funding Achieved', 
    'Status of the First Additional Funding Source as a Direct or Indirect Result of This Support': 'First AFS Status', 
    'First Additional Funding Source Agency/Sponsor Name and Project Title': 'First AFS Name and Project Title', 
    'Approximate Total Award Amount from the First Additional Funding Source': 'First AFS Amount', 
    'Status of Additional Funding Source #2 as a Direct or Indirect Result of This Support': 'Second AFS Status', 
    'Additional Funding Source #2 Agency/Sponsor Name and Project Title': 'Second AFS Name and Project Title', 
    'Approximate Total Award Amount from Additional Funding  Source #2': 'Second AFS Amount', 
    'Status of Additional Funding Source #3 as a Direct or Indirect Result of This Support': 'Third AFS Status',
    'Additional Funding Source #3 Agency/Sponsor Name and Project Title': 'Third AFS Name and Project Title',
    'Approximate Total Award Amount from Additional Funding  Source #3': 'Third AGS Amount', 
    'Status of Additional Funding Source #4 as a Direct or Indirect Result of This Support': 'Fourth AFS Status',
    'Additional Funding Source #4 Agency/Sponsor Name and Project Title': 'Fourth AFS Name and Project Title',
    'Approximate Total Award Amount from Additional Funding  Source #4': 'Fourth AFS Amount',
    'Status of Additional Funding Source #5 as a Direct or Indirect Result of This Support': 'Fifth AFS Status',
    'Approximate Total Award Amount from Additional Funding  Source #5': 'Fifth AFS Amount',
    'Would additional funding from Pedal the Cause / Curebound to a follow-on study to this project help advance the research aims established by this project? ': 'Additional Pedal Funding Impact', 
    'If yes, please briefly describe how you would use additional funding.  ': 'Additional Funding Benefits Description', 
    'Would additional funding from Pedal the Cause / Curebound help this research project advance toward clinical stages? ': 'Additional Pedal Funding Impact (clinical stages)', 
    'If yes, please briefly describe the desired outcomes of potential follow on funding. ': 'Additional Funding Benefits Description (clinical stages)', 
    'Have you participated in Padres Pedal the Cause as a rider, virtual rider, volunteer, or other role?  Please provide comments about your participation and experience at Padres Pedal the Cause events.': 'Participated in Pedal',
    'Are you aware of any significant ways in which your funded research has contributed to further research conducted by others?': 'Further Research Contributions', 
    'Did your Pedal / Curebound-funded study (and/or associated follow-on studies) yield any patient success stories?': 'Success Stories', 
    'Did your Pedal-funded study (and/or associated follow-on studies) yield any major scientific breakthroughs?': 'Major Scientific Breakthroughs',
    'Any additional comments you wish to share with Padres Pedal the Cause?': 'Additional Comments', 
    'Complete?.1': 'Complete'
}

pr = pr.rename(columns=column_mapping)

# %%
pr
# Out:
#         ID          Event Name Publication Status 4 Fourth DOI #  \
# 1      3.0  Progress Report #1                  NaN          NaN
# 3      4.0  Progress Report #1                  NaN          NaN
# 5      5.0  Progress Report #1                  NaN          NaN
# 7      6.0  Progress Report #1                  NaN          NaN
# 9      8.0  Progress Report #1                  NaN          NaN
# ..     ...                 ...                  ...          ...
# 216  133.0  Progress Report #1                  NaN          NaN
# 218  134.0  Progress Report #1                  NaN          NaN
# 220  136.0  Progress Report #1                  NaN          NaN
# 223  138.0  Progress Report #1                  NaN          NaN
# 225  139.0  Progress Report #1                  NaN          NaN
#
#     Fourth PMID or PMCID Publication Status 5 Fifth DOI # Fifth PMID or PMCID  \
# 1                    NaN                  NaN         NaN                 NaN
# ...

# %%
to_drop = [
    'Please describe the health and/or health behavior benefits expected from your project.',
    'First Additional Funding Award Period Approximate Start Date',
    'First Additional Funding Award Period Approximate End Date',
    'Can Additional Funding Source #1 Information be Shared with Padres Pedal the Cause?',
    'Additional Funding Award #2 Period Approximate Start Date', 
    'Additional Funding Award #2 Period Approximate End Date',
    'Can Additional Funding Source #2 Information be Shared with Padres Pedal the Cause?',
    'Additional Funding Award #3 Period Approximate Start Date', 
    'Additional Funding Award #3 Period Approximate End Date',
    'Can Additional Funding Source #3 Information be Shared with Padres Pedal the Cause?',
    'Additional Funding Award #4 Period Approximate Start Date', 
    'Additional Funding Award #4 Period Approximate End Date',
    'Can Additional Funding Source #4 Information be Shared with Padres Pedal the Cause?',
    'Additional Funding Award #5 Period Approximate Start Date', 
    'Additional Funding Award #5 Period Approximate End Date',
    'Can Additional Funding Source #5 Information be Shared with Padres Pedal the Cause?',
    'If yes, please specify.1',
    'May MCC and/or Pedal / Curebound reach out to you to discuss the success stories?',
    'May MCC and/or Pedal / Curebound reach out to you to discuss the major scientific breakthroughs?'
]
pr = pr.drop(columns=to_drop)

# %%
pr.head()
# Out:
#     ID          Event Name Publication Status 4 Fourth DOI #  \
# 1  3.0  Progress Report #1                  NaN          NaN
# 3  4.0  Progress Report #1                  NaN          NaN
# 5  5.0  Progress Report #1                  NaN          NaN
# 7  6.0  Progress Report #1                  NaN          NaN
# 9  8.0  Progress Report #1                  NaN          NaN
#
#   Fourth PMID or PMCID Publication Status 5 Fifth DOI # Fifth PMID or PMCID  \
# 1                  NaN                  NaN         NaN                 NaN
# 3                  NaN                  NaN         NaN                 NaN
# 5                  NaN                  NaN         NaN                 NaN
# 7                  NaN                  NaN         NaN                 NaN
# 9                  NaN                  NaN         NaN                 NaN
#
#   Publication Status 6 Sixth DOI # Sixth PMID or PMCID Publication Status 7  \
# ...

# %%
print(pr.dtypes.to_string())
# Out:
# ID                                                                    float64
# Event Name                                                             object
# Publication Status 4                                                   object
# Fourth DOI #                                                           object
# Fourth PMID or PMCID                                                   object
# Publication Status 5                                                   object
# Fifth DOI #                                                            object
# Fifth PMID or PMCID                                                    object
# Publication Status 6                                                   object
# Sixth DOI #                                                            object
# Sixth PMID or PMCID                                                    object
# Publication Status 7                                                   object
# ...

# %%
# International	 National   Local	General Public	Heathcare  Professionals  Patients	Patient Families

def impute_bool(df, col):

    # Replace Checked/Unchecked with True/False

    df[col] = df[col].replace({'Checked': True, 'Unchecked': False})
    return None

for col in pr.columns:
    if 'International' in col or 'National' in col or 'Local' in col \
        or 'General Public' in col or 'Healthcare Professionals' in col \
        or 'Patients' in col or 'Patient Families' in col:
        impute_bool(pr, col)

pr.head()
# Out:
#     ID          Event Name Publication Status 4 Fourth DOI #  \
# 1  3.0  Progress Report #1                  NaN          NaN
# 3  4.0  Progress Report #1                  NaN          NaN
# 5  5.0  Progress Report #1                  NaN          NaN
# 7  6.0  Progress Report #1                  NaN          NaN
# 9  8.0  Progress Report #1                  NaN          NaN
#
#   Fourth PMID or PMCID Publication Status 5 Fifth DOI # Fifth PMID or PMCID  \
# 1                  NaN                  NaN         NaN                 NaN
# 3                  NaN                  NaN         NaN                 NaN
# 5                  NaN                  NaN         NaN                 NaN
# 7                  NaN                  NaN         NaN                 NaN
# 9                  NaN                  NaN         NaN                 NaN
#
#   Publication Status 6 Sixth DOI # Sixth PMID or PMCID Publication Status 7  \
# ...

# %%
print(pr.dtypes.to_string())
# Out:
# ID                                                                    float64
# Event Name                                                             object
# Publication Status 4                                                   object
# Fourth DOI #                                                           object
# Fourth PMID or PMCID                                                   object
# Publication Status 5                                                   object
# Fifth DOI #                                                            object
# Fifth PMID or PMCID                                                    object
# Publication Status 6                                                   object
# Sixth DOI #                                                            object
# Sixth PMID or PMCID                                                    object
# Publication Status 7                                                   object
# ...

# %%
pr['Complete'].value_counts()
# Out:
# Complete      102
# Incomplete      2
# Name: Complete, dtype: int64

# %%
# Replace Complete/Incomplete with True/False 

pr['Complete'] = pr['Complete'].replace({'Complete': True, 'Incomplete': False})
pr.head()
# Out:
#     ID          Event Name Publication Status 4 Fourth DOI #  \
# 1  3.0  Progress Report #1                  NaN          NaN
# 3  4.0  Progress Report #1                  NaN          NaN
# 5  5.0  Progress Report #1                  NaN          NaN
# 7  6.0  Progress Report #1                  NaN          NaN
# 9  8.0  Progress Report #1                  NaN          NaN
#
#   Fourth PMID or PMCID Publication Status 5 Fifth DOI # Fifth PMID or PMCID  \
# 1                  NaN                  NaN         NaN                 NaN
# 3                  NaN                  NaN         NaN                 NaN
# 5                  NaN                  NaN         NaN                 NaN
# 7                  NaN                  NaN         NaN                 NaN
# 9                  NaN                  NaN         NaN                 NaN
#
#   Publication Status 6 Sixth DOI # Sixth PMID or PMCID Publication Status 7  \
# ...

# %%
# Get proportions of null in each column

(pr.isna().sum() / pr.shape[0]).sort_values(ascending=False)
# Out:
# Eighth PMID or PMCID       0.990385
# Sixth DOI #                0.990385
# Tenth PMID or PMCID        0.990385
# Tenth DOI #                0.990385
# Ninth PMID or PMCID        0.990385
#                              ...
# International (equity)     0.000000
# National (equity)          0.000000
# Local (equity)             0.000000
# General Public (equity)    0.000000
# Complete                   0.000000
# Length: 86, dtype: float64

# %%
roi.shape
# Out:
# (190, 232)

# %%
# Drop all completely empty columns

all_empty_cols = roi.isna().sum() == 190
to_drop = all_empty_cols[all_empty_cols].index

# %%
roi = roi.drop(columns=to_drop)

# %%
roi.head()
# Out:
#    Record ID Event Name  Award ID  \
# 0        3.0    Initial       3.1
# 2        4.0    Initial       4.1
# 4        5.0    Initial       5.1
# 6        6.0    Initial       6.1
# 8        8.0    Initial       8.1
#
#                           What is the project title?  \
# 0  Detecting dysregulated genes in neuroblastoma ...
# 2  Functional Roles for Histidine Kinase Signalin...
# 4  A National Phase I Study of Cabozantinib in Co...
# 6  UCSD-UCSF Specialized Program of Research Exce...
# 8  A Phase 1B, Nonrandomized Trial Investigating ...
#
#   What is the PI's First Name? What is the PI's last name?   PI degree  \
# 0                       Graham                    McVicker         PhD
# 2                        Peter                        Zage  MD and PhD
# 4                        Peter                        Zage  MD and PhD
# 6                       Silvio                     Gutkind         PhD
# 8                         Rana                       McKay          MD
#
# ...

# %%
# Replace Checked/Unchecked with True/False

look_for = ['Checked', 'Unchecked']

for col in roi.columns:
    if roi[col].dtype == object:
        if np.sum(roi[col].str.contains('Checked|Unchecked')) > 0:
            impute_bool(roi, col)

# %%
roi.head(1)
# Out:
#    Record ID Event Name  Award ID  \
# 0        3.0    Initial       3.1
#
#                           What is the project title?  \
# 0  Detecting dysregulated genes in neuroblastoma ...
#
#   What is the PI's First Name? What is the PI's last name? PI degree  \
# 0                       Graham                    McVicker       PhD
#
#   If other degree, please specify What is the PI's institution?   \
# 0                             NaN                 Salk Institute
#
#   If other institution, please specify    PI email address  \
# 0                                  NaN  gmcvicker@salk.edu
#
#   How many additional co-PIs are there on this study?   \
# 0                               One additional co-PI
#
#   What is #1 Co-PI's first name? What is #1 Co-PI's last name?  \
# 0                       Jennifer                        Elster
#
#   What is #1 Co-PI's degree? If #1 degree is other, please specify  \
# 0                         MD                                   NaN
#
# ...

# %%
roi["If other institution, please specify"].unique()
# Out:
# array([nan, 'City of Hope'], dtype=object)

# %%
print(roi.columns.to_list())
# Out:
# ['Record ID', 'Event Name', 'Award ID', 'What is the project title?', "What is the PI's First Name?", "What is the PI's last name?", 'PI degree', 'If other degree, please specify', "What is the PI's institution? ", 'If other institution, please specify', 'PI email address', 'How many additional co-PIs are there on this study? ', "What is #1 Co-PI's first name?", "What is #1 Co-PI's last name?", "What is #1 Co-PI's degree?", 'If #1 degree is other, please specify', "What is #1 Co-PI's Institution? ", 'If #1 institution is other, please specify', "What is #2 Co-PI's first name?", "What is #2 Co-PI's last name?", "What is #2 Co-PI's degree?", 'If #2 degree is other, please specify', "What is #2 Co-PI's Institution? ", 'If #2 institution is other, please specify', "What is #3 Co-PI's first name?", "What is #3 Co-PI's last name?", "What is #3 Co-PI's degree?", "What is #3 Co-PI's Institution? ", 'If #3 institution is other, please specify', "Which 'Curebound Pillars' does this project fal
# ...

# %%
roi_pubs = roi[['Record ID', 'Status of the first Peer Reviewed Publication associated with this support. ', 'First DOI #', 'First PMID or PMCID', 'Status of the second Peer Reviewed Publication associated with this support. ', 'Second DOI #', 'Second PMID or PMCID', 'Status of the third Peer Reviewed Publication associated with this support. ', 'Third DOI #', 'Third PMID or PMCID']]

# %%
roi_pubs
# Out:
#      Record ID  \
# 0          3.0
# 2          4.0
# 4          5.0
# 6          6.0
# 8          8.0
# ..         ...
# 289      203.0
# 290      204.0
# 291      205.0
# 292      206.0
# 293      207.0
#
#     Status of the first Peer Reviewed Publication associated with this support.   \
# 0                                             Accepted
# 2                                             Accepted
# 4                                            Published
# 6                                          In progress
# 8                                                  NaN
# ..                                                 ...
# 289                                                NaN
# 290                                                NaN
# 291                                                NaN
# 292                                                NaN
# 293                                                NaN
#
#     First DOI # First PMID or PMCID  \
# ...

# %%
# Drop PMID and PMCID columns and rename (shorten) retaining columns

roi_pubs = roi_pubs.loc[:, ~roi_pubs.columns.str.contains('PMID|PMCID')]
roi_pubs = roi_pubs.rename(columns={
    'Record ID': 'ID',
    'Status of the first Peer Reviewed Publication associated with this support. ': 'Publication Status 1',
    'Status of the second Peer Reviewed Publication associated with this support. ': 'Publication Status 2',
    'Status of the third Peer Reviewed Publication associated with this support. ': 'Publication Status 3'}
)
roi_pubs
# Out:
#         ID Publication Status 1 First DOI # Publication Status 2 Second DOI #  \
# 0      3.0             Accepted         NaN                  NaN          NaN
# 2      4.0             Accepted         NaN            Submitted          NaN
# 4      5.0            Published         NaN                  NaN          NaN
# 6      6.0          In progress         NaN          In progress          NaN
# 8      8.0                  NaN         NaN                  NaN          NaN
# ..     ...                  ...         ...                  ...          ...
# 289  203.0                  NaN         NaN                  NaN          NaN
# 290  204.0                  NaN         NaN                  NaN          NaN
# 291  205.0                  NaN         NaN                  NaN          NaN
# 292  206.0                  NaN         NaN                  NaN          NaN
# 293  207.0                  NaN         NaN                  NaN          NaN
#
# ...

# %%
# Merging roi_pubs (publications) with pr dataframe (progress report)
prog_r = pr.merge(roi_pubs, on='ID')

# Drop PMID and PMCID columns and rename (shorten) retaining columns
prog_r = prog_r.loc[:, ~prog_r.columns.str.contains('PMID|PMCID')]

# %%
prog_r.head()
# Out:
#     ID          Event Name Publication Status 4 Fourth DOI #  \
# 0  3.0  Progress Report #1                  NaN          NaN
# 1  4.0  Progress Report #1                  NaN          NaN
# 2  5.0  Progress Report #1                  NaN          NaN
# 3  6.0  Progress Report #1                  NaN          NaN
# 4  8.0  Progress Report #1                  NaN          NaN
#
#   Publication Status 5 Fifth DOI # Publication Status 6 Sixth DOI #  \
# 0                  NaN         NaN                  NaN         NaN
# 1                  NaN         NaN                  NaN         NaN
# 2                  NaN         NaN                  NaN         NaN
# 3                  NaN         NaN                  NaN         NaN
# 4                  NaN         NaN                  NaN         NaN
#
#   Publication Status 7 Seventh DOI # Publication Status 8 Eighth DOI #  \
# 0                  NaN           NaN                  NaN          NaN
# ...

# %% [markdown]
# #### Number of peer-reviewed publications (DM)

# %%
to_keep = ['Record ID',
 'Event Name',
 'Award ID',
 'What is the project title?',
 "What is the PI's institution? ",
 'If other institution, please specify',
 "Which 'Curebound Pillars' does this project fall under? Check at least one pillar and up to five. (choice=Prevention and diagnostic tools)",
 "Which 'Curebound Pillars' does this project fall under? Check at least one pillar and up to five. (choice=Novel approaches and new therapeutic platforms)",
 "Which 'Curebound Pillars' does this project fall under? Check at least one pillar and up to five. (choice=Immunotherapies and personalized vaccines)",
 "Which 'Curebound Pillars' does this project fall under? Check at least one pillar and up to five. (choice=Addressing cancer disparities)",
 "Which 'Curebound Pillars' does this project fall under? Check at least one pillar and up to five. (choice=Pediatric cancers)",
 'How many specific aims does this project have?',
 'Specific Aim #1',
 'Specific Aim #2',
 'Specific Aim #3',
 'Specific Aim #4',
 'Specific Aim #5',
 'Specific Aim #6',
 'Public Health Significance (from lay abstract)',
 'Total Amount of Award:',
 'Grant Start Date:',
 'Grant End Date:',
 'Complete?',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=None of the Below)',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Biobehavioral - MCC)',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Biorepository & Tissue Technology - MCC)',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Biostatistics - MCC)',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Clinical Trials Office - MCC)',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Flow Cytometry - MCC)',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Genomics & Computational Biology - MCC)',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=In Vivo Imaging - MCC)',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Microscopy - MCC)',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Radiation Medicine - MCC)',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Transgenic Mouse - MCC)',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Gene Transfer/Targeting/Therap - Salk)',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Transgenic - Salk)',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Mass Spect - Proteom/Metabol- Salk)',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Chemical Library Screening - SBPMDI)',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Functional Genomics - SBPMDI)',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Cancer Metabolism - SBPMDI)',
 'Was Pedal the Cause funding an important part of your recruitment, retention, or advancement?',
 'If yes, please specify',
 'If no, please specify',
 'How many clinical trials have resulted from your study?',
 'What is the name of the first clinical trial?',
 'How many patients enrolled in first clinical trial?',
 'What is the name of the second clinical trial?',
 'How many patients enrolled in the second clinical trial?',
 'What are the names of any companies founded as a result of your study?',
 'Did you file any patents based on your study?',
 'If yes, please add the details of the filed patents here.',
 'How many peer reviewed publications do you have, or are you working on, that are associated with this support? '
]

# %%
roi = roi[to_keep]

# %%
# roi.columns.to_list()

# %%
# Shortening column names

# Dict for renaming columns
column_mapping = {
 'Record ID': 'ID',
 'What is the project title?': 'Project Title',
 "What is the PI's institution? ": 'PI Institution',
 'If other institution, please specify': 'Other Institution',
 "Which 'Curebound Pillars' does this project fall under? Check at least one pillar and up to five. (choice=Prevention and diagnostic tools)": 'Prevention and diagnostic tools',
 "Which 'Curebound Pillars' does this project fall under? Check at least one pillar and up to five. (choice=Novel approaches and new therapeutic platforms)": 'Novel approaches and new therapeutic platforms',
 "Which 'Curebound Pillars' does this project fall under? Check at least one pillar and up to five. (choice=Immunotherapies and personalized vaccines)": 'Immunotherapies and personalized vaccines',
 "Which 'Curebound Pillars' does this project fall under? Check at least one pillar and up to five. (choice=Addressing cancer disparities)": 'Addressing cancer disparities',
 "Which 'Curebound Pillars' does this project fall under? Check at least one pillar and up to five. (choice=Pediatric cancers)": 'Pediatric cancers',
 'How many specific aims does this project have?': 'Specific Aims',
 'Specific Aim #1': 'Aim 1',
 'Specific Aim #2': 'Aim 2',
 'Specific Aim #3': 'Aim 3',
 'Specific Aim #4': 'Aim 4',
 'Specific Aim #5': 'Aim 5',
 'Specific Aim #6': 'Aim 6',
 'Public Health Significance (from lay abstract)': 'Public Health Significance',
 'Total Amount of Award:': 'Award Amount',
 'Complete?': 'Complete',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=None of the Below)': 'SR - None',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Biobehavioral - MCC)': 'SR - Biobehaviorial MCC',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Biorepository & Tissue Technology - MCC)': 'SR - Biorepository & Tissue Tech. MCC',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Biostatistics - MCC)': 'SR - Biostatistics MCC',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Clinical Trials Office - MCC)': 'SR - Clinical Trials Office MCC',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Flow Cytometry - MCC)': 'SR - Flow Cytometry MCC',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Genomics & Computational Biology - MCC)': 'SR - Genomics & Computational Bio. MCC',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=In Vivo Imaging - MCC)': 'SR - In Vivo Imaging MCC',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Microscopy - MCC)': 'SR - Microscopy MCC',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Radiation Medicine - MCC)': 'SR - Radiation Medicine MCC',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Transgenic Mouse - MCC)': 'SR - Transgenic Mouse MCC',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Gene Transfer/Targeting/Therap - Salk)': 'SR - Gene Transfer/Targeting/Therap Salk',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Transgenic - Salk)': 'SR - Transgenic Salk',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Mass Spect - Proteom/Metabol- Salk)': 'SR - Mass Spect - Proteom/Metabol Salk',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Chemical Library Screening - SBPMDI)': 'SR - Chemical Library Screening SBPMDI',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Functional Genomics - SBPMDI)': 'SR - Functional Genomics SBPMDI',
 'Shared Resources Utilized:  Value Added by the Cancer Center(s)     (choice=Cancer Metabolism - SBPMDI)': 'Cancer Metabolism SBPMDI',
 'Was Pedal the Cause funding an important part of your recruitment, retention, or advancement?': 'Pedal Importance (recruitment, retention, advancement)',
 'How many clinical trials have resulted from your study?': 'Clinical Trials Resulted',
 'What is the name of the first clinical trial?': 'First Clinical Trial',
 'How many patients enrolled in first clinical trial?': 'First Clinical Trial Patient Count',
 'What is the name of the second clinical trial?': 'Second Clinical Trial',
 'How many patients enrolled in the second clinical trial?': 'Second Clinical Trial Patient Count',
 'What are the names of any companies founded as a result of your study?': 'Companies Founded',
 'Did you file any patents based on your study?': 'Patents Filed',
 'If yes, please add the details of the filed patents here.': 'Patent Details',
 'How many peer reviewed publications do you have, or are you working on, that are associated with this support? ': 'Peer-Reviewed Publications Count'
}

roi = roi.rename(columns=column_mapping)

# %%
roi.head()
# Out:
#     ID Event Name  Award ID  \
# 0  3.0    Initial       3.1
# 2  4.0    Initial       4.1
# 4  5.0    Initial       5.1
# 6  6.0    Initial       6.1
# 8  8.0    Initial       8.1
#
#                                        Project Title        PI Institution  \
# 0  Detecting dysregulated genes in neuroblastoma ...        Salk Institute
# 2  Functional Roles for Histidine Kinase Signalin...       Rady Children's
# 4  A National Phase I Study of Cabozantinib in Co...       Rady Children's
# 6  UCSD-UCSF Specialized Program of Research Exce...  Moores Cancer Center
# 8  A Phase 1B, Nonrandomized Trial Investigating ...  Moores Cancer Center
#
#   Other Institution  Prevention and diagnostic tools  \
# 0               NaN                            False
# 2               NaN                            False
# 4               NaN                            False
# 6               NaN                            False
# 8               NaN                            False
#
# ...

# %%
prog_r.head()
# Out:
#     ID          Event Name Publication Status 4 Fourth DOI #  \
# 0  3.0  Progress Report #1                  NaN          NaN
# 1  4.0  Progress Report #1                  NaN          NaN
# 2  5.0  Progress Report #1                  NaN          NaN
# 3  6.0  Progress Report #1                  NaN          NaN
# 4  8.0  Progress Report #1                  NaN          NaN
#
#   Publication Status 5 Fifth DOI # Publication Status 6 Sixth DOI #  \
# 0                  NaN         NaN                  NaN         NaN
# 1                  NaN         NaN                  NaN         NaN
# 2                  NaN         NaN                  NaN         NaN
# 3                  NaN         NaN                  NaN         NaN
# 4                  NaN         NaN                  NaN         NaN
#
#   Publication Status 7 Seventh DOI # Publication Status 8 Eighth DOI #  \
# 0                  NaN           NaN                  NaN          NaN
# ...

# %%
# Save cleaned dataframes to csv files in interim
# Caution: examine directory before uncomment/run this cell to prevent duplicate
# files or unintentional modifications to files

# wp = os.path.join('interim', '2022_Pedal_ROI.csv')
# roi.to_csv(wp)

# wp = os.path.join('interim', '2022_Pedal_Progress_Report.csv')
# prog_r.to_csv(wp)
